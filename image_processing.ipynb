# %%
import numpy as np
from scipy.constants import e, m_p, m_e, c, epsilon_0, m_n, k as kb
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import pandas as pd
from cycler import cycler
from scipy.interpolate import interp1d
import glob, os
from scipy.odr import ODR, Model, RealData
from astropy.io import fits

plt.rcParams.update({
    # Color cycle
    "axes.prop_cycle": cycler('color', ['#0C5DA5', '#00B945', '#FF9500', '#FF2C00', '#845B97', '#474747', '#9e9e9e']),

    # Figure size
    "figure.figsize": (4, 3),

    # X ticks
    "xtick.direction": "in",
    "xtick.major.size": 3,
    "xtick.major.width": 0.5,
    "xtick.minor.size": 1.5,
    "xtick.minor.width": 0.5,
    "xtick.minor.visible": True,
    "xtick.top": True,

    # Y ticks
    "ytick.direction": "in",
    "ytick.major.size": 3,
    "ytick.major.width": 0.5,
    "ytick.minor.size": 1.5,
    "ytick.minor.width": 0.5,
    "ytick.minor.visible": True,
    "ytick.right": True,

    # Axes & lines
    "axes.linewidth": 0.5,
    "grid.linewidth": 0.5,
    "lines.linewidth": 1.0,

    # Font & math
    "font.family": "sans-serif",
    #"mathtext.fontset": "dejavuserif",
    "text.usetex": True,
    "text.latex.preamble": r"\usepackage{amsmath} \usepackage{amssymb}",

    # Legend & saving
    "legend.frameon": False,
    "savefig.bbox": "tight",
    "savefig.pad_inches": 0.05
})

# %% [markdown]
# # Reading the data

# %%
hdulist = fits.open("data/Fits_Data/mosaic.fits")
hdulist[0].header
# Out:
# SIMPLE  =                    T / Fits standard
# BITPIX  =                   16 / Bits per pixel
# NAXIS   =                    2 / Number of axes
# NAXIS1  =                 2570 / Axis length
# NAXIS2  =                 4611 / Axis length
# EXTEND  =                    F / File may contain extensions
# BSCALE  =           1.000000E0 / REAL = TAPE*BSCALE + BZERO
# BZERO   =           3.276800E4 /
# ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator
# DATE    = '2006-03-20T14:56:47' / Date FITS file was generated
# IRAF-TLM= '14:56:45 (20/03/2006)' / Time of last modification
# OBJECT  = 'Lockman_mosaic_r_1046+5902 - DelRA =   0.0, DelDec =   0.0' / Name of
# NEXTEND =                    8 / Number of extensions
# FILENAME= 'obj4110 '           / Original host filename
# RADECSYS= 'FK5     '           / Default coordinate system
#
# TIMESYS = 'UTC approximate'    / Time system
# MJDHDR  =       52324.25847222 / MJD of header creation
#
# OBSERVAT= 'KPNO    '           / Observatory
# TELESCOP= 'KPNO 4.0 meter telescope' / Telescope
# TELRADEC= 'FK5     '           / Telescope coordinate system
# TELEQUIN=               2000.0 / Equinox of tel coords
# TELRA   = '10:46:00.00       ' / RA of telescope (hr)
# TELDEC  = '59:02:00.0        ' / DEC of telescope (deg)
# ZD      = '34.1133           ' / Zenith distance
# AIRMASS =                1.207 / Airmass
# TELFOCUS=                -7442 / Telescope focus
# CORRCTOR= 'Mayall Corrector'   / Corrector Identification
# ADC     = 'Mayall ADC'         / ADC Identification
# ADCSTAT = 'track             ' / ADC tracking state null-track-preset
# ADCPAN1 =  1.3210000000000E+01 / ADC 1 prism angle
# ADCPAN2 =  4.3230000000000E+01 / ADC 2 prism angle
#
# DETECTOR= 'CCDMosaThin1'       / Detector
# DETSIZE = '[1:8192,1:8192]'    / Detector size for DETSEC
# NCCDS   =                    8 / Number of CCDs
# NAMPS   =                    8 / Number of Amplifiers
# PIXSIZE1=                  15. / Pixel size for axis 1 (microns)
# PIXSIZE2=                  15. / Pixel size for axis 2 (microns)
# PIXSCAL1=                0.258 / Pixel scale for axis 1 (arcsec/pixel)
# PIXSCAL2=                0.258 / Pixel scale for axis 2 (arcsec/pixel)
# RAPANGL =                   0. / Position angle of RA axis (deg)
# DECPANGL=                  90. / Position angle of DEC axis (deg)
# FILPOS  =                   11 / Filter position
# SHUTSTAT= 'guide             ' / Shutter status
# TV1FOC  = -1.9900000000000E-01 / North TV Camera focus position
# TV2FOC  = -1.7060000000000E+00 / South Camera focus position
# ENVTEM  =  2.2000000000000E+00 / Ambient temperature (C)
# DEWAR   = 'CCDMosaThin1 Dewar' / Dewar identification
# DEWTEM  = -1.7080000300000E+02 / Dewar temperature (C)
# DEWTEM2 = -2.1000000000000E+01 / Fill Neck temperature (C)
# DEWTEM3 = 'N2   0.0'
# CCDTEM  = -1.0259999800000E+02 / CCD temperature  (C)
# CCDTEM2 = 'CCD   0.0'
# CONSWV  = '2.000  13Feb96     (add mode and group to hdrs)' / Controller softwar
#
# OBSERVER= 'Siana, Morrison, Farrah' / Observer(s)
# PROPOSER= '<unknown>'          / Proposer(s)
# PROPOSAL= '<unknown>'          / Proposal title
# PROPID  = '2002A 0402'         / Proposal identification
#
# IMAGESWV= 'mosdca (Jun99), mosaic.tcl (Aug00)' / Image creation software version
# KWDICT  = 'MosaicV1.dic (Sep97)' / Keyword dictionary
#
# OTFDIR  = 'mscdb$noao/kpno/4meter/caldir/' / OTF calibration directory
# XTALKFIL= 'mscdb$noao/CCDMosaThin1/CAL0009/xtalk0009' / Crosstalk file
#
# CHECKSUM= '<unknown>'          / Header checksum
# DATASUM = '<unknown>'          / Data checksum
# RECNO   =                    0 / NOAO archive sequence number
# IMAGEID =                    1 / Image identification
# OBSID   = 'kp4m.20020219T061210' / Observation ID
#
# OBSTYPE = 'object  '           / Observation type
# EXPTIME =              720.000 / Exposure time in secs
# DARKTIME=              722.287 / Total elapsed time in secs
# PREFLASH=             0.000000 / Preflash time (sec)
# FILTER  = 'r SDSS 1018       ' / Filter name(s)
#
# RA      = '10:46:00.00'        / RA of observation (hr)
# DEC     = '59:01:59.99'        / DEC of observation (deg)
# RADECEQ =                2000. / Default equinox
# DATE-OBS= '2002-02-19T06:12:10.7' / Date of observation start (UTC approximate)
# TIME-OBS= '06:12:10.7'         / Time of observation start
# MJD-OBS =       52324.25845718 / MJD of observation start
# LSTHDR  = '8:41:55           ' / LST of header creation
#
# CCDNAME = 'SITe #7298FBR06-01 (NOAO 14)' / CCD name
# AMPNAME = 'SITe #7298FBR06-01 (NOAO 14), lower right (Amp12)' / Amplifier name
# GAIN    =                  3.1 / gain expected for amp 112 (e-/ADU)
# RDNOISE =                  5.6 / read noise expected for amp 112 (e-)
# SATURATE=                36000 / Maximum good data value (ADU)
# CONTROLR= 'Mosaic Arcon'       / Controller identification
# CONHWV  = 'ACEB001_AMP12'      / Controller hardware version
# AMPINTEG=                 3600 / (ns) Double Correlated Sample time
# READTIME=                14400 / (ns) unbinned pixel read time
# ARCONWD = 'Obs Mon Feb 18 18:37:34 2002' / Date waveforms last compiled
# ARCONWM = 'OverlapXmit EarlyReset SplitShift ' / Waveform mode switches on
# ARCONGI =                    2 / Gain selection (index into Gain Table)
# ARCONG  =                  3.1 / gain expected for amp 112 (e-/ADU)
# ARCONRN =                  5.6 / read noise expected for amp 112 (e-)
# BPM     = 'mscdb$noao/CCDMosaThin1/CAL0009/bpm1_0009' / Bad pixel mask
# CCDSIZE = '[1:2048,1:4096]'    / CCD size
# CCDSUM  = '1 1     '           / CCD pixel summing
# CCDSEC  = '[1:2048,1:4096]'    / CCD section
# AMPSEC  = '[2072:25,1:4096]'   / Amplifier section
# DATASEC = '[1:2570,1:4611]'    / Data section
# DETSEC  = '[1:2048,1:4096]'    / Detector section
# BIASSEC = '[1:50,1:4096]'      / Bias section
# TRIMSEC = '[65:2112,1:4096]'   / Trim section
#
# ATM1_1  =                  -1. / CCD to amplifier transformation
# ATM2_2  =                   1. / CCD to amplifier transformation
# ATV1    =               2073.0 / CCD to amplifier transformation
# ATV2    =                   0. / CCD to amplifier transformation
# LTM1_1  =                  1.0 / CCD to image transformation
# LTM2_2  =                  1.0 / CCD to image transformation
# LTV1    =                  0.0 / CCD to image transformation
# LTV2    =                  0.0 / CCD to image transformation
# DTM1_1  =                   1. / CCD to detector transformation
# DTM2_2  =                   1. / CCD to detector transformation
# DTV1    =                   0. / CCD to detector transformation
# DTV2    =                   0. / CCD to detector transformation
#
# WCSASTRM= 'kp4m.19981010T033325 (Tr 37 V) by L. Davis 19981010' / WCS Source
# EQUINOX =                2000. / Equinox of WCS
# WCSDIM  =                    2 / WCS dimensionality
# CTYPE1  = 'RA---ZPN'           / Coordinate type
# CTYPE2  = 'DEC--ZPN'           / Coordinate type
# CRVAL1  =        1.6152225E+02 / Coordinate reference value
# CRVAL2  =        5.9028858E+01 / Coordinate reference value
# CRPIX1  =        4.4930000E+03 / Coordinate reference pixel
# CRPIX2  =        4.2190000E+03 / Coordinate reference pixel
# CD1_1   =        2.0446110E-07 / Coordinate matrix
# CD2_1   =       -7.2792674E-05 / Coordinate matrix
# CD1_2   =       -7.2730247E-05 / Coordinate matrix
# CD2_2   =       -1.4360739E-07 / Coordinate matrix
# WAT0_001= 'system=image'       / Coordinate system
# WAT1_001= 'wtype=tnx axtype=ra lngcor = "1. 4. 4. 2. 0.001350110541305456 0.296'
# WAT1_002= '1134983164539 0.1527300838880007 0.3005743086989888 -2.3148854055725'
# WAT1_003= '20E-4 -2.544362379374634E-5 -5.388234193153857E-4 -8.922255888845757'
# WAT1_004= 'E-5 -8.302381045554778E-5 -5.480973389725749E-4 -1.278609167401606E-'
# WAT1_005= '5 -4.552906776144391E-5 -5.085009960518193E-5 1.494933829648152E-6 "'
# WAT2_001= 'wtype=tnx axtype=dec latcor = "1. 4. 4. 2. 0.001350110541305456 0.29'
# WAT2_002= '61134983164539 0.1527300838880007 0.3005743086989888 -2.139239182123'
# WAT2_003= '121E-4 1.511975415985664E-5 -2.737123763921002E-4 6.094554322351407E'
# WAT2_004= '-6 -1.277938927468220E-4 -3.661387318373361E-4 -8.567151810206574E-5'
# WAT2_005= ' -2.095855623216569E-4 2.007952901140182E-6 -1.218760716077907E-5 "'
#
# CHECKVER= '<unknown>'          / Checksum version
# PEDESTAL=                  0.0 / Artificial pedestal added to data
# PROJP1  =             1.00E+00 / &
# PROJP3  =             3.75E+02 / &
# NUMBRMS =                   53 / Number of standards used
# STDCRMS =            2.400E-01 / Astrometric fit error (arcsec)
# PERCORR =           -6.000E-03 / Sky calibration correction (mags)
# MAGZPT  =            2.530E+01 / Photometric ZP (mags) for default extinction
# MAGZRR  =            2.000E-02 / Photometric ZP error (mags)
# PV2_1   =             1.00E+00 / &
# PV2_3   =             3.75E+02 / &

# %%
hdulist[0].data
# Out:
# array([[3421, 3421, 3421, ..., 3421, 3421, 3421],
#        [3421, 3421, 3421, ..., 3421, 3421, 3421],
#        [3421, 3421, 3421, ..., 3421, 3421, 3421],
#        ...,
#        [3421, 3421, 3421, ..., 3421, 3421, 3421],
#        [3421, 3421, 3421, ..., 3421, 3421, 3421],
#        [3421, 3421, 3421, ..., 3421, 3421, 3421]], dtype=uint16)
